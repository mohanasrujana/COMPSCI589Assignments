# %%
import sympy as sp
from sympy import init_printing
init_printing(use_latex=True)

pi, N0, N1, Ntr = sp.symbols('pi N0 N1 Ntr', positive=True)

nall = -(1/Ntr)*(N1*sp.log(pi) + N0*sp.log(1 - pi))
print("nall(pi,D) = ")
display(nall)
# Out:
# nall(pi,D) =
# -(N₀⋅log(1 - π) + N₁⋅log(π))
# ─────────────────────────────
#              Ntr

# %%
nall_grad = sp.diff(nall, pi)
display(nall_grad)
# Out:
#  ⎛   N₀     N₁⎞
# -⎜- ───── + ──⎟
#  ⎝  1 - π   π ⎠
# ────────────────
#       Ntr

# %%
pi_cap = sp.solve(sp.Eq(sp.simplify(dnall_dpi), 0), pi)
print("pi^ = ")
display(pi_cap)
# Out:
# pi^ =
# ⎡  N₁   ⎤
# ⎢───────⎥
# ⎣N₀ + N₁⎦
